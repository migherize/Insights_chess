# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
from sklearn.preprocessing import normalize

# %%
dataframe = pd.read_csv("/Users/migherize/SourceTree/Insights_chess/src/Data_enginner/output/Cluster.csv")
dataframe.head()
# Out:
#           Jugador  Partidas  Victoria Blancas  Tablas Blancas  \
# 0   danielbarreto     17113              4769             283
# 1  jhoseim_torres        20                 1               0
# 2         mherize      4060              1063              96
# 3        rirr2020       894               205               5
# 4        juandv12      2847               655              88
#
#    Perdidas Blancas  Victorias Negras  Tablas Negras  Perdidas Negras
# 0              3713              4548            290             3510
# 1                 8                 0              1               10
# 2               899              1042             99              861
# 3               266               179              5              234
# 4               687               678             57              682
